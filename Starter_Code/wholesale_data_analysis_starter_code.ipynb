# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
#      Use the count function to  see if there are any missing values in the data and see column names

#      Use the dtypes function to  see type of data for each column
print(df.dtypes)
# Out:
# first           object
# last            object
# job             object
# phone           object
# email           object
# client_id        int64
# order_id         int64
# order_date      object
# order_week       int64
# order_year       int64
# item_id         object
# category        object
# subcategory     object
# unit_price     float64
# unit_cost      float64
# unit_weight    float64
# qty              int64
# line_number      int64
# dtype: object

# %%
# What three item categories had the most entries?
#   using value count function
df["category"].value_counts().head(3)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries, which subcategory had the most entries?
#   look at consumables only, then use value count function 
df.loc[df['category'] == "consumables"]["subcategory"].value_counts().head(1)
# Out:
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

# %%
# Which five clients had the most entries in the data?
#   use value counts function on client_id column
df["client_id"].value_counts().head()
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
#   create list from client_id, use value counts 
# list(df["client_id"].value_counts().head().index)
top_five_clients = list(df["client_id"].value_counts().head().index)
print(top_five_clients)
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the client with the most entries order order?
#   find all rows with client id 33615 and sum the qty


df.loc[df["client_id"] == 33615, "qty"].sum()
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
#   subtotal = unit_price * qty
#   add new column "subtotal"

df['subtotal'] = df['unit_price'] * df['qty']
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.
#   if order_weight >50, calculate shipping price at $7 * unit_weight
#   if order_weight <=50, $10 * unit weight
#   add new column "shipping_price"

# df['shipping_price'] = df.apply(lambda df: 7 * (row['unit_weight'] * row['qty']) if (row['unit_weight'] * row['qty']) > 50 else 10 * (row['unit_weight'] * row['qty']))
# df.head()
df['order_weight'] = df['unit_weight'] * df['qty']
df['shipping_price'] = df.apply(lambda row: 7 * row['order_weight'] if row['order_weight'] > 50 else 10 * row['order_weight'], axis=1)
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...     category         subcategory unit_price  \
# ...

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%


df['total_price'] = df['total_price'] = (df['subtotal'] + df['shipping_price']) * 1.0925
df['total_price'] = df['total_price'].round(2)
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...         subcategory unit_price unit_cost  \
# ...

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).
#   create new column "line_cost"
#   line_cost=(unit_cost+shipping_price)*qty
df['line_cost'] = (df['unit_cost'] * df['qty']) + df['shipping_price']
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_price unit_cost unit_weight  qty  \
# ...

# %%
# Create a column for the profit of each line using line cost and line price
#   create new column "profit"
#   profit = subtotal- line_cost
df['profit'] = df['total_price'] - df['line_cost']
df = df.round(2)
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_cost unit_weight  qty  line_number  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above

order_2742071 = df[df['order_id'] == 2742071]
total_price_2742071 = order_2742071['total_price'].sum()
print(f"order 2742071 total: ${total_price_2742071:.2f}")

order_2173913 = df[df['order_id'] == 2173913]
total_price_2173913 = order_2173913['total_price'].sum()
print(f"order 2173913 total: ${total_price_2173913:.2f}")

order_6128929 = df[df['order_id'] == 6128929]
total_price_6128929 = order_6128929['total_price'].sum()
print(f"order 6128929 total: ${total_price_6128929:.2f}")
# Out:
# order 2742071 total: $152811.89
# order 2173913 total: $162388.71
# order 6128929 total: $923441.25

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
top_clients_data = df[df['client_id'].isin(top_five_clients)]

# Calculate the sum of total_price for each top client
total_price_sum_per_client = top_clients_data.groupby('client_id')['total_price'].sum().reset_index()

# Convert total_price to numeric type
total_price_sum_per_client['total_price'] = total_price_sum_per_client['total_price'].astype(float)

# Format the currency values for better display
total_price_sum_per_client['total_price'] = total_price_sum_per_client['total_price'].map('${:,.2f}'.format)

# Displaying the sum of total_price for each top client
print(total_price_sum_per_client)
# Out:
#    client_id     total_price
# 0      24741  $82,268,892.02
# 1      33615   $8,377,308.52
# 2      38378  $12,906,550.87
# 3      46820   $9,743,794.36
# 4      66037  $10,259,514.79

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit. 

summary_df = df[df['client_id'].isin(top_five_clients)]
summed_values = summary_df.groupby('client_id').agg({
    'qty': 'sum',
    'shipping_price': 'sum',
    'total_price': 'sum',
    'line_cost': 'sum',
    'profit': 'sum'
}).reset_index()

# filtered_orders
summed_values.head()
# Out:
#    client_id     qty  shipping_price  total_price    line_cost       profit
# 0      24741  239862      5126448.37  82268892.02  45688899.71  36579992.31
# 1      33615   64313      1828984.89   8377308.52   6175313.91   2201994.61
# 2      38378   73667      3429455.40  12906550.87   9634720.98   3271829.89
# 3      46820   75768      1601448.84   9743794.36   7007191.64   2736602.72
# 4      66037   43018      1395151.85  10259514.79   7004482.98   3255031.81

# %%
# Format the data and rename the columns to names suitable for presentation.

# Define the money columns. 


# Define a function that converts a dollar amount to millions.


# Apply the currency_format_millions function to only the money columns. 


# Rename the columns to reflect the change in the money format. 



summed_values_formatted = summed_values.rename(columns={'client_id':"Client ID",
                                                        'qty':'Units',
                                                        'shipping_price':'Shipping (millions)',
                                                        'total_price':'Total Revenue (millions)',
                                                        'line_cost':'Total Cost (millions)',
                                                        'profit':'Total Profit (millions)'})
summed_values_formatted.head()

def convert_to_millions(x):
    return '${:,.2f}M'.format(x / 1000000)

money_columns = ['Shipping (millions)', 'Total Revenue (millions)', 'Total Cost (millions)', 'Total Profit (millions)']

summed_values_formatted[money_columns] = summed_values_formatted[money_columns].apply(lambda x: x.apply(convert_to_millions))

summed_values_formatted
# Out:
#    Client ID   Units Shipping (millions) Total Revenue (millions)  \
# 0      24741  239862     $5.13M             $82.27M
# 1      33615   64313     $1.83M              $8.38M
# 2      38378   73667     $3.43M             $12.91M
# 3      46820   75768     $1.60M              $9.74M
# 4      66037   43018     $1.40M             $10.26M
#
#   Total Cost (millions) Total Profit (millions)
# 0    $45.69M               $36.58M
# 1     $6.18M                $2.20M
# 2     $9.63M                $3.27M
# 3     $7.01M                $2.74M
# 4     $7.00M                $3.26M

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
formatted_sorted = summed_values_formatted.sort_values('Total Profit (millions)', ascending=False)
formatted_sorted
# Out:
#    Client ID   Units Shipping (millions) Total Revenue (millions)  \
# 0      24741  239862     $5.13M             $82.27M
# 2      38378   73667     $3.43M             $12.91M
# 4      66037   43018     $1.40M             $10.26M
# 3      46820   75768     $1.60M              $9.74M
# 1      33615   64313     $1.83M              $8.38M
#
#   Total Cost (millions) Total Profit (millions)
# 0    $45.69M               $36.58M
# 2     $9.63M                $3.27M
# 4     $7.00M                $3.26M
# 3     $7.01M                $2.74M
# 1     $6.18M                $2.20M

# %% [markdown]
# ####    The top five most profitable clients generated combined revenues of 123.56 million (USD) and a net profit of 48.05 million(USD). There are two key observations revealed in this analysis:
# #####   The averages for Total Revenue, Total Cost, and Total Profit are heavily weighted by the most profitable client, 24741;this needs to be considered in any subsequent analyses of the full data to ensure that reporting averages is not skewed  by the results of a single client.
# #####   The Cost to Revenue ratio for client 24741 is significantly lower in comparison to the remaining top four clients; further analysis is reccomended to understand why they are so much more profitable in relation to the other top clients.
